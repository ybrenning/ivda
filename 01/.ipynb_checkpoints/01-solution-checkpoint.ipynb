# %%
import csv

import pandas as pd

df = pd.read_csv('data/Aufgabe-1.csv', on_bad_lines='skip')
# Out:
# /tmp/ipykernel_68402/1229868957.py:6: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/Aufgabe-1.csv', on_bad_lines='skip')

# %%
df.head()
# Out:
#          'Known As'           'Full Name'  'Overall'  'Potential'  \
# 0        'L. Messi'        'Lionel Messi'         91           91
# 1  'R. Lewandowski'  'Robert Lewandowski'         91           91
# 2        'M. Salah'       'Mohamed Salah'         90           90
# 3     'T. Courtois'    'Thibaut Courtois'         90           91
# 4        'M. Neuer'        'Manuel Neuer'         90           90
#
#   'Value(in Euro)' 'Positions Played' 'Best Position' 'Nationality'  \
# 0         54000000               'RW'           'CAM'   'Argentina'
# 1         84000000               'ST'            'ST'      'Poland'
# 2        115500000               'RW'            'RW'       'Egypt'
# 3         90000000               'GK'            'GK'     'Belgium'
# 4         13500000               'GK'            'GK'     'Germany'
#
#                                         'Image Link'  'Age'  ...  'LM Rating'  \
# ...

# %%
df.shape
# Out:
# (9022, 89)
